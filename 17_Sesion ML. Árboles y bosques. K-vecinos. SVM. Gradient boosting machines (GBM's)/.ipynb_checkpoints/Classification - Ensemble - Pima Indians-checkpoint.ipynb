# %% [markdown]
# ## The Data: Pima Indian Classification

# %% [markdown]
# ### Problem statement
# Using the UCI PIMA Indian Diabetes dataset to predict a person has diabetes or not using the medical attributes provided. (Target is column 8)
#
# ### Assumptions
#
# This is enough data to split and reliably predict if the patient has diabetes, the dataset has only 786 data points
# Just these attributes are enough to diagnose the ailment
# Similar Problems
# This is very much like some common 2 class classification problems like classifying mail into spam and ham based on the contents of the email. Obviously the attributes there would be strings and not numbers like this dataset, therefore the way in which we process at least some of the features will be different.

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("data/pima-indians-diabetes.data",header=None)

# %%
df.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
X=df[np.arange(8)]
y=df[8]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
clf = LogisticRegression()

# %%
cross_val_score(clf,X,y,scoring="accuracy",cv=10).mean()
# Out:
# 0.7669685577580314

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
clfk = GridSearchCV(KNeighborsClassifier(n_neighbors=1),
                   param_grid={"n_neighbors":range(2,40)},
                   scoring="accuracy",
                   cv=10)
clfk.fit(X,y)
clfk.best_score_
# Out:
# 0.7552083333333334

# %%
# RBF 
0.65
# Out:
# 0.65

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clfd = GridSearchCV(DecisionTreeClassifier(min_samples_leaf=20,max_depth=3),
                   param_grid={"min_samples_leaf":[10,20,30,50,100],
                               "max_depth":range(2,7)},
                   scoring="accuracy",
                   cv=10)
clfd.fit(X,y)
clfd.best_score_
# Out:
# 0.7395833333333334

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
clf.fit(X_train,y_train)
clfk.fit(X_train,y_train)
clfd.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=20, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'min_samples_leaf': [10, 20, 30, 50, 100], 'max_depth': range(2, 7)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
from sklearn.ensemble import VotingClassifier

# %%
clfv = VotingClassifier(estimators=[("log",clf),("kneigh",clfk),("dec",clfd)])

# %%
cross_val_score(clfv,X,y,scoring="accuracy",cv=10).mean()
# Out:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.7643711551606289

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import BaggingClassifier

# %%
clfb = BaggingClassifier(base_estimator=KNeighborsClassifier(n_neighbors=16),n_estimators=100)

# %%
cross_val_score(clfb,X,y,scoring="accuracy",cv=10).mean()
# Out:
# 0.7435406698564593

# %%
clfb = BaggingClassifier(base_estimator=KNeighborsClassifier(n_neighbors=16),
                         n_estimators=100,
                        oob_score=True)

# %%
clfb.fit(X,y)
# Out:
# BaggingClassifier(base_estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=16, p=2,
#            weights='uniform'),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=100, n_jobs=1, oob_score=True,
#          random_state=None, verbose=0, warm_start=False)

# %%
clfb.oob_score_
# Out:
# 0.7421875

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clfr = RandomForestClassifier(min_samples_leaf=30,n_estimators=200,oob_score=True)

# %%
cross_val_score(clfr,X,y,scoring="accuracy",cv=10).mean()
# Out:
# 0.7487354750512645

# %%
clfr.fit(X,y)
clfr.oob_score_
# Out:
# 0.7565104166666666

# %%
clfr.estimators_[0]
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=30, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False,
#             random_state=1054912238, splitter='best')

# %%
from IPython.display import Image  
from sklearn import tree
import pydotplus

# %%
dot_data = tree.export_graphviz(clfr.estimators_[3], out_file=None, 
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
plt.plot(clfr.feature_importances_)

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
clfa = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=6),
                          n_estimators=100)

# %%
cross_val_score(clfa,X,y,scoring="accuracy",cv=10).mean()
# Out:
# 0.7369617224880384

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clfb = GradientBoostingClassifier(n_estimators=100)

# %%
cross_val_score(clfb,X,y,scoring="accuracy",cv=10).mean()
# Out:
# 0.7617053998632947

# %%
from xgboost import XGBClassifier

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
clfxb = XGBClassifier(n_estimators=100)

# %%
cross_val_score(clfxb,X,y,scoring="accuracy",cv=10).mean()
# Out:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /Users/sebastien.perez/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.7694805194805194
