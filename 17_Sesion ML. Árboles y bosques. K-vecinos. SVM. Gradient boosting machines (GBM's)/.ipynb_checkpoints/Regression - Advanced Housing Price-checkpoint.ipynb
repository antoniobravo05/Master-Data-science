# %% [markdown]
# # House Pricing
#
# ## Problem Statement
#
# We would like to predict the house of a house based on its characteristics.

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("data/house_prices.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#¿Como cojo los datos y se los meto al modelo?¿Que pasa con las variables categóricas?...
#Para ver todo esto:

df.hist(figsize=(20,10));

#Creamos un histograma de todas las caracteristicas del Dataset. Así podemos ver que es categorico y que numérico

# %%
#con un df.describe() solo se muestran las numéricas
#con df.types me dice que tipo es cada una de ellas

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
#Primero vamos a trabajar con VARIABLES NUMÉRICAS.
#selecciono solo los que sean flotantes, si quisiera un entero "int64".
df.select_dtypes(include=["int64","float64"])
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# 5        6          50         85.0    14115            5            5
# 6        7          20         75.0    10084            8            5
# 7        8          60          NaN    10382            7            6
# 8        9          50         51.0     6120            7            5
# 9       10         190         50.0     7420            5            6
# 10      11          20         70.0    11200            5            5
# 11      12          60         85.0    11924            9            5
# ...

# %%
#ejemplo con el yearsold
#lo quiero convertir a string
df["YrSold"]=df["YrSold"].astype(str)

# %%
dfm=df.select_dtypes(include=["int64","float64"])
dfm.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1    ...      GarageArea  WoodDeckSF  \
# 0          2003       196.0         706    ...             548           0
# 1          1976         0.0         978    ...             460         298
# 2          2002       162.0         486    ...             608           0
# 3          1970         0.0         216    ...             642           0
# 4          2000       350.0         655    ...             836         192
#
# ...

# %%
#examino el precio de venta
#plt.figure(size=20)
plt.hist(df["SalePrice"],bins=100);

# %%
#vemos que hay outlayers, la cola es muy larga. Esto me influye mucho en la media. Y todos los metodos estan usando la media.

# %%
plt.scatter(df["LotArea"],df["SalePrice"])

# %%
#vemos que hay una relacion muy lineal, podemos quedarnos con los que quedan muy apartados de la aglomeracion
dfn=df[(df["LotArea"]<50000)&(df["SalePrice"]<600000)].copy()

# %%
plt.scatter(dfn["LotArea"],dfn["SalePrice"])

# %%
#estudio de la correlacion entre los datos
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(dfn.corr())

# %%
#queremos quitar las variables que estén muy correladas para quitar los probemas de multicolinealidad.
#habría que investigar las relaciones más claras fuera de la diagonal. Y elegir, quitar alguna.

# %%
#MISSING VALUES
for col in df.columns:
    print (col)
    print (len(df[df[col].isnull()]))
# Out:
# Id
# 0
# MSSubClass
# 0
# MSZoning
# 0
# LotFrontage
# 259
# LotArea
# 0
# Street
# 0
# Alley
# 1369
# LotShape
# 0
# LandContour
# 0
# Utilities
# 0
# LotConfig
# 0
# LandSlope
# 0
# Neighborhood
# 0
# Condition1
# 0
# Condition2
# 0
# BldgType
# 0
# HouseStyle
# 0
# OverallQual
# 0
# OverallCond
# 0
# YearBuilt
# 0
# YearRemodAdd
# 0
# RoofStyle
# 0
# RoofMatl
# 0
# Exterior1st
# 0
# Exterior2nd
# 0
# MasVnrType
# 8
# MasVnrArea
# 8
# ExterQual
# 0
# ExterCond
# 0
# Foundation
# 0
# BsmtQual
# 37
# BsmtCond
# 37
# BsmtExposure
# 38
# BsmtFinType1
# 37
# BsmtFinSF1
# 0
# BsmtFinType2
# 38
# BsmtFinSF2
# 0
# BsmtUnfSF
# 0
# TotalBsmtSF
# 0
# Heating
# 0
# HeatingQC
# 0
# CentralAir
# 0
# Electrical
# 1
# 1stFlrSF
# 0
# 2ndFlrSF
# 0
# LowQualFinSF
# 0
# GrLivArea
# 0
# BsmtFullBath
# 0
# BsmtHalfBath
# 0
# FullBath
# 0
# HalfBath
# 0
# BedroomAbvGr
# 0
# KitchenAbvGr
# 0
# KitchenQual
# 0
# TotRmsAbvGrd
# 0
# Functional
# 0
# Fireplaces
# 0
# FireplaceQu
# 690
# GarageType
# 81
# ...

# %%
#para quitar los missing values que vemos que hay:
len(df)
# Out:
# 1460

# %%
len(df.dropna())
# Out:
# 0

# %%
#Osea que todas las filas tienen valores perdidos.
#Puedo quitarme culumnas donde falten cosas, o puedo imputar valores

#en este caso es una variable categórica, sustituimos los n/a por N/S
df["FireplaceQu"]=df["FireplaceQu"].fillna("N/S")

# %%
#voy a buscar una columna con un nº imcompleto, por ejemplo LotFrontage.
from sklearn.preprocessing import Imputer

imp=Imputer()
#completará con la media de esa columna

# %%
imp.fit_transform(df[["LotFrontage","MasVnrArea"]])
#para series temporales, podemos interpolar.
#el problema es cuando tengo datos que no siguen ningun orden, por eso se suele usar la media.
#otra forma es hacer un modelo de ML que según el valor del resto de valores, deducir su valor
# Out:
# array([[ 65., 196.],
#        [ 80.,   0.],
#        [ 68., 162.],
#        ...,
#        [ 66.,   0.],
#        [ 68.,   0.],
#        [ 75.,   0.]])

# %%
#TRATAMIENTO DE VARIABLES CATEGÓRICAS

#ver en notebook Mushrooms

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
lbe=LabelEncoder()
one=OneHotEncoder()

# %%
df["YrSold"].head()
# Out:
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008
# Name: YrSold, dtype: object

# %%
df["YrSold"]=lbe.fit_transform(df["YrSold"])
one.fit_transform(df[["YrSold"]])
# Out:
# <1460x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1460 stored elements in Compressed Sparse Row format>

# %%
#el aviso es pq no es una matriz normal y lo guarda en otra posicion de memoria.

# %%
#ESCALADO

#todas las variables necesitamos que estén en ela misma escala. QUe no estén en lamisma escala afectará a algoritmos basados en distancia.

from sklearn.preprocessing import RobustScaler

# %%
plt.hist()

# %%
#rbs=RobustScaler()
#X_n=rbs.fit_transform[df[[]]]
#...

# %%
#conclusion, hay que escalar siempre.

# %%
#PIPELINES

from sklearn.pipeline import Pipeline

#Podemos poner que haga el escalado y pasarle el algoritmo a la vez.
